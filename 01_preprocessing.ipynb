# %%
from build_df import build_dataframe
import pandas as pd
from analyze_files import build_folder_summary

df_meta = build_dataframe()

df_meta
# Out:
# Number of .txt files found:  2540
#                                             source_path temp_folder_label  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# ...                                                 ...               ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2536  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2537  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2538  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2539  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
#
#       deltaT_label  T_plate_label series_id channel_raw channel_norm  \
# 0              0.0             23        15         CH1            Y
# 1              0.0             23        15         CH1            Y
# 2              0.0             23        15         CH1            Y
# 3              0.0             23        15         CH1            Y
# 4              0.0             23        15         CH1            Y
# ...            ...            ...       ...         ...          ...
# 2535          45.7             75        27         CH2            X
# 2536          45.7             75        27         CH2            X
# 2537          45.7             75        27         CH2            X
# 2538          45.7             75        27         CH2            X
# 2539          45.7             75        27         CH2            X
#
#      pressure_raw_label  pressure_corr_mpa      point_type  \
# 0                0.5MPa                0.5  pressure_point
# 1                0.5MPa                0.5  pressure_point
# 2                0.5MPa                0.5  pressure_point
# 3                0.5MPa                0.5  pressure_point
# 4                0.5MPa                0.5  pressure_point
# ...                 ...                ...             ...
# 2535               9MPa                9.0  pressure_point
# 2536               9MPa                9.0  pressure_point
# 2537               9MPa                9.0  pressure_point
# 2538               9MPa                9.0  pressure_point
# 2539               9MPa                9.0  pressure_point
#
#                                                 pair_id  is_complete_pair  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...              True
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...              True
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...              True
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...              True
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...              True
# ...                                                 ...               ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...              True
# 2536  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...              True
# 2537  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...              True
# 2538  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...              True
# 2539  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...              True
#
#                                       reference_zero_id  is_temp_calibration  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...                False
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...                False
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...                False
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...                False
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...                False
# ...                                                 ...                  ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...                False
# 2536  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...                False
# 2537  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...                False
# 2538  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...                False
# 2539  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...                False
#
#       is_pressure_calibration  is_joint_regression  is_repeatability_test
# 0                        True                 True                  False
# 1                        True                 True                  False
# 2                        True                 True                  False
# 3                        True                 True                  False
# 4                        True                 True                  False
# ...                       ...                  ...                    ...
# 2535                    False                 True                  False
# 2536                    False                 True                  False
# 2537                    False                 True                  False
# 2538                    False                 True                  False
# 2539                    False                 True                  False
#
# [2540 rows x 17 columns]

# %%
#df_summary = build_folder_summary(df_meta)
df_summary = pd.read_csv("training_dataset.csv")
df_summary
# Out:
# Building summary: 100%|██████████| 1270/1270 [00:41<00:00, 30.35it/s]
#              folder  pressure    dT  Tp       mu_Y       mu_X     std_Y  \
# 0        DT0_T23_15       0.5   0.0  23  -1.161463   0.177174  0.148690
# 1        DT0_T23_15       0.5   0.0  23  -1.134390   0.160566  0.142894
# 2        DT0_T23_15       0.5   0.0  23  -1.149027   0.174392  0.144446
# 3        DT0_T23_15       0.5   0.0  23  -1.142649   0.179321  0.144685
# 4        DT0_T23_15       0.5   0.0  23  -1.140869   0.169717  0.146148
# ...             ...       ...   ...  ..        ...        ...       ...
# 1265  DT45.7_T75_27       9.0  45.7  75 -82.669577 -59.543071  1.117709
# 1266  DT45.7_T75_27       9.0  45.7  75 -82.685232 -59.550092  1.124685
# 1267  DT45.7_T75_27       9.0  45.7  75 -82.669424 -59.548976  1.122806
# 1268  DT45.7_T75_27       9.0  45.7  75 -82.656679 -59.529346  1.123449
# 1269  DT45.7_T75_27       9.0  45.7  75 -82.662247 -59.548707  1.119223
#
#          std_X     irq_Y     irq_X  ...  \
# 0     0.080380  0.208516  0.103947  ...
# 1     0.082127  0.211629  0.107682  ...
# 2     0.078795  0.204315  0.100057  ...
# 3     0.080948  0.201047  0.102702  ...
# 4     0.080401  0.217230  0.102702  ...
# ...        ...       ...       ...  ...
# 1265  1.085852  2.134331  2.233070  ...
# 1266  1.084317  2.148346  2.237428  ...
# 1267  1.083446  2.139313  2.226298  ...
# 1268  1.085689  2.144920  2.235169  ...
# 1269  1.087563  2.117844  2.239214  ...
#
#                                                  path_x  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# ...                                                 ...
# 1265  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1266  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1267  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1268  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1269  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
#
#                                                     ref  low_quality  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# ...                                                 ...          ...
# 1265  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1266  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1267  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1268  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1269  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
#
#       y_quality y_quality_ref x_quality x_quality_ref  series_id    diff_XY  \
# 0      0.993451      1.000000  0.994875      0.995729         15   1.338638
# 1      0.982346      0.998576  0.990319      0.995444         15   1.294956
# 2      0.987472      0.999146  0.993736      0.997153         15   1.323419
# 3      0.984339      0.999715  0.992312      0.997153         15   1.321970
# 4      0.985478      0.999146  0.992597      0.995729         15   1.310586
# ...         ...           ...       ...           ...        ...        ...
# 1265   1.000000      1.000000  0.989468      0.990037         27  23.126506
# 1266   1.000000      1.000000  0.989468      0.989752         27  23.135139
# 1267   1.000000      1.000000  0.989468      0.989752         27  23.120448
# 1268   1.000000      1.000000  0.989752      0.990037         27  23.127333
# 1269   1.000000      1.000000  0.989468      0.990037         27  23.113540
#
#         mean_XY
# 0     -0.492145
# 1     -0.486912
# 2     -0.487318
# 3     -0.481664
# 4     -0.485576
# ...         ...
# 1265 -71.106324
# 1266 -71.117662
# 1267 -71.109200
# 1268 -71.093012
# 1269 -71.105477
#
# [1270 rows x 25 columns]

# %%
df_summary.isnull().sum()
# Out:
# folder                     0
# pressure                   0
# dT                         0
# Tp                         0
# mu_Y                       0
# mu_X                       0
# std_Y                      0
# std_X                      0
# irq_Y                      0
# irq_X                      0
# is_temp_calibration        0
# is_pressure_calibration    0
# is_joint_regression        0
# is_repeatability_test      0
# path_y                     0
# path_x                     0
# ref                        0
# low_quality                0
# y_quality                  0
# y_quality_ref              0
# x_quality                  0
# x_quality_ref              0
# series_id                  0
# diff_XY                    0
# mean_XY                    0
# dtype: int64

# %%
df_summary[df_summary["ref"].notna()]
# Out:
#              folder  pressure    dT  Tp       mu_Y       mu_X     std_Y  \
# 0        DT0_T23_15       0.5   0.0  23  -1.161463   0.177174  0.148690
# 1        DT0_T23_15       0.5   0.0  23  -1.134390   0.160566  0.142894
# 2        DT0_T23_15       0.5   0.0  23  -1.149027   0.174392  0.144446
# 3        DT0_T23_15       0.5   0.0  23  -1.142649   0.179321  0.144685
# 4        DT0_T23_15       0.5   0.0  23  -1.140869   0.169717  0.146148
# ...             ...       ...   ...  ..        ...        ...       ...
# 1265  DT45.7_T75_27       9.0  45.7  75 -82.669577 -59.543071  1.117709
# 1266  DT45.7_T75_27       9.0  45.7  75 -82.685232 -59.550092  1.124685
# 1267  DT45.7_T75_27       9.0  45.7  75 -82.669424 -59.548976  1.122806
# 1268  DT45.7_T75_27       9.0  45.7  75 -82.656679 -59.529346  1.123449
# 1269  DT45.7_T75_27       9.0  45.7  75 -82.662247 -59.548707  1.119223
#
#          std_X     irq_Y     irq_X  ...  \
# 0     0.080380  0.208516  0.103947  ...
# 1     0.082127  0.211629  0.107682  ...
# 2     0.078795  0.204315  0.100057  ...
# 3     0.080948  0.201047  0.102702  ...
# 4     0.080401  0.217230  0.102702  ...
# ...        ...       ...       ...  ...
# 1265  1.085852  2.134331  2.233070  ...
# 1266  1.084317  2.148346  2.237428  ...
# 1267  1.083446  2.139313  2.226298  ...
# 1268  1.085689  2.144920  2.235169  ...
# 1269  1.087563  2.117844  2.239214  ...
#
#                                                  path_x  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# ...                                                 ...
# 1265  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1266  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1267  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1268  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1269  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
#
#                                                     ref  low_quality  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        False
# ...                                                 ...          ...
# 1265  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1266  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1267  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1268  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
# 1269  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...        False
#
#       y_quality y_quality_ref x_quality x_quality_ref  series_id    diff_XY  \
# 0      0.993451      1.000000  0.994875      0.995729         15   1.338638
# 1      0.982346      0.998576  0.990319      0.995444         15   1.294956
# 2      0.987472      0.999146  0.993736      0.997153         15   1.323419
# 3      0.984339      0.999715  0.992312      0.997153         15   1.321970
# 4      0.985478      0.999146  0.992597      0.995729         15   1.310586
# ...         ...           ...       ...           ...        ...        ...
# 1265   1.000000      1.000000  0.989468      0.990037         27  23.126506
# 1266   1.000000      1.000000  0.989468      0.989752         27  23.135139
# 1267   1.000000      1.000000  0.989468      0.989752         27  23.120448
# 1268   1.000000      1.000000  0.989752      0.990037         27  23.127333
# 1269   1.000000      1.000000  0.989468      0.990037         27  23.113540
#
#         mean_XY
# 0     -0.492145
# 1     -0.486912
# 2     -0.487318
# 3     -0.481664
# 4     -0.485576
# ...         ...
# 1265 -71.106324
# 1266 -71.117662
# 1267 -71.109200
# 1268 -71.093012
# 1269 -71.105477
#
# [1270 rows x 25 columns]

# %%
df_base_for_training = df_summary[df_summary["ref"].notna()][["pressure", "dT", "Tp", "mu_Y", "mu_X",  "is_temp_calibration", "is_pressure_calibration", "is_joint_regression", "is_repeatability_test", "low_quality", "x_quality", "x_quality_ref", "y_quality", "y_quality_ref"]]
df_base_for_training[df_base_for_training["x_quality"] > 0.9]
# Out:
#       pressure    dT  Tp       mu_Y       mu_X  is_temp_calibration  \
# 0          0.5   0.0  23  -1.161463   0.177174                False
# 1          0.5   0.0  23  -1.134390   0.160566                False
# 2          0.5   0.0  23  -1.149027   0.174392                False
# 3          0.5   0.0  23  -1.142649   0.179321                False
# 4          0.5   0.0  23  -1.140869   0.169717                False
# ...        ...   ...  ..        ...        ...                  ...
# 1265       9.0  45.7  75 -82.669577 -59.543071                False
# 1266       9.0  45.7  75 -82.685232 -59.550092                False
# 1267       9.0  45.7  75 -82.669424 -59.548976                False
# 1268       9.0  45.7  75 -82.656679 -59.529346                False
# 1269       9.0  45.7  75 -82.662247 -59.548707                False
#
#       is_pressure_calibration  is_joint_regression  is_repeatability_test  \
# 0                        True                 True                  False
# 1                        True                 True                  False
# 2                        True                 True                  False
# 3                        True                 True                  False
# 4                        True                 True                  False
# ...                       ...                  ...                    ...
# 1265                    False                 True                  False
# 1266                    False                 True                  False
# 1267                    False                 True                  False
# 1268                    False                 True                  False
# 1269                    False                 True                  False
#
#       low_quality  x_quality  x_quality_ref  y_quality  y_quality_ref
# 0           False   0.994875       0.995729   0.993451       1.000000
# 1           False   0.990319       0.995444   0.982346       0.998576
# 2           False   0.993736       0.997153   0.987472       0.999146
# 3           False   0.992312       0.997153   0.984339       0.999715
# 4           False   0.992597       0.995729   0.985478       0.999146
# ...           ...        ...            ...        ...            ...
# 1265        False   0.989468       0.990037   1.000000       1.000000
# 1266        False   0.989468       0.989752   1.000000       1.000000
# 1267        False   0.989468       0.989752   1.000000       1.000000
# 1268        False   0.989752       0.990037   1.000000       1.000000
# 1269        False   0.989468       0.990037   1.000000       1.000000
#
# [1232 rows x 14 columns]

# %%
from utils import quality_report


print(quality_report(df_base_for_training, 0.9))
# Out:
# total                     1270
# low_quality_original        45
# low_quality_recomputed     114
# x_good                    1232
# x_ref_good                1270
# y_good                    1262
# y_ref_good                1186
# all_good                  1156
# dtype: int64

# %%
print(f"is_temp_calibration: {df_base_for_training["is_temp_calibration"].sum()}")
print(f"is_pressure_calibration: {df_base_for_training["is_pressure_calibration"].sum()}")
print(f"is_joint_regression: {df_base_for_training["is_joint_regression"].sum()}")
print(f"is_repeatability_test: {df_base_for_training["is_repeatability_test"].sum()}")
# Out:
# is_temp_calibration: 90
# is_pressure_calibration: 120
# is_joint_regression: 1270
# is_repeatability_test: 60

# %%
# Zad. 14.1

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

sns.histplot(df_meta['deltaT_label'], kde=False, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title('Rozkład temperatur (deltaT)')

sns.histplot(df_meta['pressure_corr_mpa'], kde=False, ax=axes[0, 1], color='salmon')
axes[0, 1].set_title('Rozkład ciśnień (MPa)')

df_meta['point_type'].value_counts().plot(kind='pie', autopct='%1.1f%%', ax=axes[0, 2])
axes[0, 2].set_title('Udział typów punktów (point_type)')

df_meta['series_id'].value_counts().head(10).plot(kind='bar', ax=axes[1, 0])
axes[1, 0].set_title('Rozkład 10 najczęstszych serii')

fig.delaxes(axes[1, 2])
plt.tight_layout()
plt.show()

# %%
df_meta["pressure_num"] = (
    df_meta["pressure_raw_label"]
    .str.replace("MPa", "", regex=False)
    .astype(float)
)

middle = sorted(
    x for x in df_meta["pressure_num"].unique()
    if x not in [0, 0.01, 11]
)

x_order_num = [0] + middle + [0.01, 11]

x_order_labels = [f"{x:g} MPa" for x in x_order_num]

# Create categorical labels
df_meta["pressure_plot"] = pd.Categorical(
    df_meta["pressure_num"].map(lambda x: f"{x:g} MPa"),
    categories=x_order_labels,
    ordered=True
)

# OPTIONAL: same idea for temperature axis
temp_order = sorted(df_meta["T_plate_label"].unique())

df_meta["temp_plot"] = pd.Categorical(
    df_meta["T_plate_label"],
    categories=temp_order,
    ordered=True
)

# Count combinations
counts = (
    df_meta.groupby(["pressure_plot", "temp_plot"])
    .size()
    .reset_index(name="count")
)

# Plot
plt.figure(figsize=(12, 6))

sns.scatterplot(
    data=counts,
    x="pressure_plot",
    y="temp_plot",
    size="count",
    hue="count",
    palette="bright",
    sizes=(50, 1000),
    legend=True
)

plt.xticks(rotation=35)

plt.xlabel("Pressure")
plt.ylabel("Temperature")
plt.title("Counts of pressure + temperature combinations")

plt.grid(True)

plt.show()

# %%
# Zad. 14.2

df_plot = df_summary[df_summary["ref"].notna()].copy()

# 3 wykresy obok siebie
fig, axes = plt.subplots(1, 3, figsize=(21, 6))

# =========================
# 1. mu_X vs dT
# =========================
for e in df_plot['pressure'].unique():
    df_p = df_plot[df_plot['pressure'] == e]

    sns.regplot(
        data=df_p,
        x='dT',
        y='mu_X',
        ax=axes[0],
        label=f'p={e}',
        scatter_kws={'s': 40}
    )

axes[0].set_title('mu_X vs Temperatura')
axes[0].set_xlabel('dT')
axes[0].set_ylabel('mu_X [GHz]')
axes[0].legend(title='Ciśnienie', bbox_to_anchor=(1.02, 1),loc='upper left')


# =========================
# 2. mu_Y vs dT
# =========================
for e in df_plot['pressure'].unique():
    df_p = df_plot[df_plot['pressure'] == e]

    sns.regplot(
        data=df_p,
        x='dT',
        y='mu_Y',
        ax=axes[1],
        label=f'p={e}',
        scatter_kws={'s': 40}
    )

axes[1].set_title('mu_Y vs Temperatura')
axes[1].set_xlabel('dT')
axes[1].set_ylabel('mu_Y [GHz]')
axes[1].legend(title='Ciśnienie', bbox_to_anchor=(1.02, 1),loc='upper left')


# =========================
# 3. mu_X i mu_Y vs pressure
# =========================
df_p = df_plot[df_plot['dT'] == 0]

sns.regplot(
    data=df_p,
    x='pressure',
    y='mu_X',
    ax=axes[2],
    label='mu_X',
    scatter_kws={'s': 40}
)

sns.regplot(
    data=df_p,
    x='pressure',
    y='mu_Y',
    ax=axes[2],
    label='mu_Y',
    scatter_kws={'s': 40}
)

axes[2].set_title('Przesunięcie widmowe vs Ciśnienie (dT=0)')
axes[2].set_xlabel('Ciśnienie')
axes[2].set_ylabel('mu [GHz]')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
# Zad. 14.3

features = ['dT', 'pressure', 'mu_X', 'mu_Y', 'diff_XY', 'mean_XY']
corr_matrix = df_plot[features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Macierz korelacji cech bazowych z parametrami docelowymi')
plt.show()

corr_p_diff = corr_matrix.loc['pressure', 'diff_XY']
corr_p_muX = corr_matrix.loc['pressure', 'mu_X']
corr_T_mean = corr_matrix.loc['dT', 'mean_XY']
corr_T_muX = corr_matrix.loc['dT', 'mu_X']

print(f"Korelacja p z diff_XY: {corr_p_diff:.4f} (vs mu_X: {corr_p_muX:.4f})")
print(f"Korelacja dT z mean_XY: {corr_T_mean:.4f} (vs mu_X: {corr_T_muX:.4f})")

print("Wnioski:")
if abs(corr_p_diff) > abs(corr_p_muX):
    print(" -diff_XY poprawia korelację z ciśnieniem względem pojedynczego kanału.")
else:
    print(" -diff_XY nie wykazuje silniejszej korelacji liniowej z ciśnieniem niż mu_X.")

if abs(corr_T_mean) > abs(corr_T_muX):
    print(" -mean_XY poprawia korelację z temperaturą względem pojedynczego kanału.")
else:
    print(" -mean_XY nie wykazuje silniejszej korelacji liniowej z temperaturą niż mu_X.")
# Out:
# Korelacja p z diff_XY: 0.9994 (vs mu_X: 0.1907)
# Korelacja dT z mean_XY: -0.9939 (vs mu_X: -0.9918)
# Wnioski:
#  -diff_XY poprawia korelację z ciśnieniem względem pojedynczego kanału.
#  -mean_XY poprawia korelację z temperaturą względem pojedynczego kanału.
