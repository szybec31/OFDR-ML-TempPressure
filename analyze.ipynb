# %%
from build_df import build_dataframe
from analyze_files import build_folder_summary

df_meta = build_dataframe()

df_meta
# Out:
# Number of .txt files found:  2540
#                                             source_path temp_folder_label  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...        DT0_T23_15
# ...                                                 ...               ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2536  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2537  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2538  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
# 2539  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...     DT45.7_T75_27
#
#       deltaT_label  T_plate_label series_id channel_raw channel_norm  \
# 0              0.0             23        15         CH1            Y
# 1              0.0             23        15         CH1            Y
# 2              0.0             23        15         CH1            Y
# 3              0.0             23        15         CH1            Y
# 4              0.0             23        15         CH1            Y
# ...            ...            ...       ...         ...          ...
# 2535          45.7             75        27         CH2            X
# 2536          45.7             75        27         CH2            X
# 2537          45.7             75        27         CH2            X
# 2538          45.7             75        27         CH2            X
# 2539          45.7             75        27         CH2            X
#
#      pressure_raw_label  pressure_corr_mpa      point_type  \
# 0                0.5MPa                0.5  pressure_point
# 1                0.5MPa                0.5  pressure_point
# 2                0.5MPa                0.5  pressure_point
# 3                0.5MPa                0.5  pressure_point
# 4                0.5MPa                0.5  pressure_point
# ...                 ...                ...             ...
# 2535               9MPa                9.0  pressure_point
# 2536               9MPa                9.0  pressure_point
# 2537               9MPa                9.0  pressure_point
# 2538               9MPa                9.0  pressure_point
# 2539               9MPa                9.0  pressure_point
#
#                                                 pair_id  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# ...                                                 ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 2536  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 2537  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 2538  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 2539  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
#
#                                             role  is_complete_pair  \
# 0     EDA;pressure_calibration;joint_regression;              True
# 1     EDA;pressure_calibration;joint_regression;              True
# 2     EDA;pressure_calibration;joint_regression;              True
# 3     EDA;pressure_calibration;joint_regression;              True
# 4     EDA;pressure_calibration;joint_regression;              True
# ...                                          ...               ...
# 2535                       EDA;joint_regression;              True
# 2536                       EDA;joint_regression;              True
# 2537                       EDA;joint_regression;              True
# 2538                       EDA;joint_regression;              True
# 2539                       EDA;joint_regression;              True
#
#                                       reference_zero_id
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# ...                                                 ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 2536  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 2537  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 2538  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 2539  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
#
# [2540 rows x 14 columns]

# %%
df_summary = build_folder_summary(df_meta)

df_summary
# Out:
# Building summary: 100%|██████████| 1270/1270 [00:50<00:00, 25.27it/s]
#              folder  pressure    dT  Tp       mu_Y      mu_X     std_Y  \
# 0        DT0_T23_15       0.5   0.0  23  -1.140635  0.195342  0.157742
# 1        DT0_T23_15       0.5   0.0  23  -1.103324  0.183002  0.155500
# 2        DT0_T23_15       0.5   0.0  23  -1.132613  0.193438  0.153673
# 3        DT0_T23_15       0.5   0.0  23  -1.120898  0.208898  0.153838
# 4        DT0_T23_15       0.5   0.0  23  -1.115012  0.199869  0.154969
# ...             ...       ...   ...  ..        ...       ...       ...
# 1175  DT45.7_T75_27       9.0  45.7  75 -17.393602  6.353061  0.437057
# 1176  DT45.7_T75_27       9.0  45.7  75 -17.392781  6.335698  0.432674
# 1177  DT45.7_T75_27       9.0  45.7  75 -17.387492  6.334266  0.439144
# 1178  DT45.7_T75_27       9.0  45.7  75 -17.357476  6.360441  0.446468
# 1179  DT45.7_T75_27       9.0  45.7  75 -17.375052  6.322131  0.433696
#
#          std_X     irq_Y     irq_X  ...  \
# 0     0.084840  0.222832  0.107682  ...
# 1     0.092324  0.223922  0.120753  ...
# 2     0.083863  0.213185  0.105814  ...
# 3     0.089605  0.210384  0.115773  ...
# 4     0.089190  0.229057  0.114528  ...
# ...        ...       ...       ...  ...
# 1175  0.284974  0.753769  0.231001  ...
# 1176  0.295124  0.740082  0.228821  ...
# 1177  0.296559  0.763420  0.230459  ...
# 1178  0.284451  0.778053  0.236534  ...
# 1179  0.294889  0.761246  0.229213  ...
#
#                                                  path_y  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# ...                                                 ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1176  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1177  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1178  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1179  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
#
#                                                  path_x  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# ...                                                 ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1176  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1177  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1178  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1179  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
#
#                                                     ref low_quality  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# ...                                                 ...         ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1176  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1177  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1178  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1179  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
#
#       y_quality  y_quality_ref  x_quality  x_quality_ref    diff_XY   mean_XY
# 0      0.993451       1.000000   0.994875       0.995729   1.335978 -0.472647
# 1      0.982346       0.998576   0.990319       0.995444   1.286326 -0.460161
# 2      0.987472       0.999146   0.993736       0.997153   1.326051 -0.469588
# 3      0.984339       0.999715   0.992312       0.997153   1.329796 -0.456000
# 4      0.985478       0.999146   0.992597       0.995729   1.314881 -0.457571
# ...         ...            ...        ...            ...        ...       ...
# 1175   1.000000       1.000000   0.989468       0.990037  23.746662 -5.520270
# 1176   1.000000       1.000000   0.989468       0.989752  23.728479 -5.528542
# 1177   1.000000       1.000000   0.989468       0.989752  23.721758 -5.526613
# 1178   1.000000       1.000000   0.989752       0.990037  23.717917 -5.498518
# 1179   1.000000       1.000000   0.989468       0.990037  23.697183 -5.526460
#
# [1180 rows x 21 columns]

# %%
df_summary.isnull().sum()
# Out:
# folder           0
# pressure         0
# dT               0
# Tp               0
# mu_Y             0
# mu_X             0
# std_Y            0
# std_X            0
# irq_Y            0
# irq_X            0
# role             0
# path_y           0
# path_x           0
# ref              0
# low_quality      0
# y_quality        0
# y_quality_ref    0
# x_quality        0
# x_quality_ref    0
# diff_XY          0
# mean_XY          0
# dtype: int64

# %%
df_summary[df_summary["ref"].notna()]
# Out:
#              folder  pressure    dT  Tp       mu_Y      mu_X     std_Y  \
# 0        DT0_T23_15       0.5   0.0  23  -1.140635  0.195342  0.157742
# 1        DT0_T23_15       0.5   0.0  23  -1.103324  0.183002  0.155500
# 2        DT0_T23_15       0.5   0.0  23  -1.132613  0.193438  0.153673
# 3        DT0_T23_15       0.5   0.0  23  -1.120898  0.208898  0.153838
# 4        DT0_T23_15       0.5   0.0  23  -1.115012  0.199869  0.154969
# ...             ...       ...   ...  ..        ...       ...       ...
# 1175  DT45.7_T75_27       9.0  45.7  75 -17.393602  6.353061  0.437057
# 1176  DT45.7_T75_27       9.0  45.7  75 -17.392781  6.335698  0.432674
# 1177  DT45.7_T75_27       9.0  45.7  75 -17.387492  6.334266  0.439144
# 1178  DT45.7_T75_27       9.0  45.7  75 -17.357476  6.360441  0.446468
# 1179  DT45.7_T75_27       9.0  45.7  75 -17.375052  6.322131  0.433696
#
#          std_X     irq_Y     irq_X  ...  \
# 0     0.084840  0.222832  0.107682  ...
# 1     0.092324  0.223922  0.120753  ...
# 2     0.083863  0.213185  0.105814  ...
# 3     0.089605  0.210384  0.115773  ...
# 4     0.089190  0.229057  0.114528  ...
# ...        ...       ...       ...  ...
# 1175  0.284974  0.753769  0.231001  ...
# 1176  0.295124  0.740082  0.228821  ...
# 1177  0.296559  0.763420  0.230459  ...
# 1178  0.284451  0.778053  0.236534  ...
# 1179  0.294889  0.761246  0.229213  ...
#
#                                                  path_y  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...
# ...                                                 ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1176  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1177  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1178  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
# 1179  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...
#
#                                                  path_x  \
# 0     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 1     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 2     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 3     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# 4     PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channe...
# ...                                                 ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1176  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1177  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1178  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
# 1179  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_cha...
#
#                                                     ref low_quality  \
# 0     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 2     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 3     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# 4     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channe...       False
# ...                                                 ...         ...
# 1175  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1176  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1177  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1178  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
# 1179  PAKA_AI\DT45.7_T75_27\27_CH1_Y_FAST\Switch_cha...       False
#
#       y_quality  y_quality_ref  x_quality  x_quality_ref    diff_XY   mean_XY
# 0      0.993451       1.000000   0.994875       0.995729   1.335978 -0.472647
# 1      0.982346       0.998576   0.990319       0.995444   1.286326 -0.460161
# 2      0.987472       0.999146   0.993736       0.997153   1.326051 -0.469588
# 3      0.984339       0.999715   0.992312       0.997153   1.329796 -0.456000
# 4      0.985478       0.999146   0.992597       0.995729   1.314881 -0.457571
# ...         ...            ...        ...            ...        ...       ...
# 1175   1.000000       1.000000   0.989468       0.990037  23.746662 -5.520270
# 1176   1.000000       1.000000   0.989468       0.989752  23.728479 -5.528542
# 1177   1.000000       1.000000   0.989468       0.989752  23.721758 -5.526613
# 1178   1.000000       1.000000   0.989752       0.990037  23.717917 -5.498518
# 1179   1.000000       1.000000   0.989468       0.990037  23.697183 -5.526460
#
# [1180 rows x 21 columns]

# %%
df_base_for_training = df_summary[df_summary["ref"].notna()][["pressure", "dT", "Tp", "y_signal", "x_signal", "role", "low_quality", "x_quality", "x_quality_ref", "y_quality", "y_quality_ref"]]
df_base_for_training[df_base_for_training["x_quality"] > 0.9]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_base_for_training = df_summary[df_summary["ref"].notna()][["pressure", "dT", "Tp", "y_signal", "x_signal", "role", "low_quality", "x_quality", "x_quality_ref", "y_quality", "y_quality_ref"]]
#       2 df_base_for_training[df_base_for_training["x_quality"] > 0.9]
#
# File ~\Desktop\Made in Heaven\Studia\OFDR-ML-TempPressure\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\Desktop\Made in Heaven\Studia\OFDR-ML-TempPressure\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\Desktop\Made in Heaven\Studia\OFDR-ML-TempPressure\.venv\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['y_signal', 'x_signal'] not in index"

# %%
from utils import quality_report


print(quality_report(df_base_for_training, 0.9))
# Out:
# total                     1180
# low_quality_original       107
# low_quality_recomputed     107
# x_good                    1142
# x_ref_good                1180
# y_good                    1179
# y_ref_good                1103
# all_good                  1073
# dtype: int64

# %%
df_base_for_training[df_base_for_training["role"].str.contains("EDA")].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1180 entries, 0 to 1179
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pressure       1180 non-null   float64
#  1   dT             1180 non-null   float64
#  2   Tp             1180 non-null   int64
#  3   y_signal       1180 non-null   float64
#  4   x_signal       1180 non-null   float64
#  5   role           1180 non-null   str
#  6   low_quality    1180 non-null   bool
#  7   x_quality      1180 non-null   float64
#  8   x_quality_ref  1180 non-null   float64
#  9   y_quality      1180 non-null   float64
#  10  y_quality_ref  1180 non-null   float64
# dtypes: bool(1), float64(8), int64(1), str(1)
# memory usage: 93.5 KB

# %%
df_base_for_training[df_base_for_training["role"].str.contains("joint_regression")].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1180 entries, 0 to 1179
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pressure       1180 non-null   float64
#  1   dT             1180 non-null   float64
#  2   Tp             1180 non-null   int64
#  3   y_signal       1180 non-null   float64
#  4   x_signal       1180 non-null   float64
#  5   role           1180 non-null   str
#  6   low_quality    1180 non-null   bool
#  7   x_quality      1180 non-null   float64
#  8   x_quality_ref  1180 non-null   float64
#  9   y_quality      1180 non-null   float64
#  10  y_quality_ref  1180 non-null   float64
# dtypes: bool(1), float64(8), int64(1), str(1)
# memory usage: 93.5 KB

# %%
df_base_for_training[df_base_for_training["role"].str.contains("pressure_calibration")].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 110 entries, 0 to 119
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pressure       110 non-null    float64
#  1   dT             110 non-null    float64
#  2   Tp             110 non-null    int64
#  3   y_signal       110 non-null    float64
#  4   x_signal       110 non-null    float64
#  5   role           110 non-null    str
#  6   low_quality    110 non-null    bool
#  7   x_quality      110 non-null    float64
#  8   x_quality_ref  110 non-null    float64
#  9   y_quality      110 non-null    float64
#  10  y_quality_ref  110 non-null    float64
# dtypes: bool(1), float64(8), int64(1), str(1)
# memory usage: 9.6 KB

# %%
df_base_for_training[df_base_for_training["role"].str.contains("repeatability_test")].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 60 entries, 20 to 1089
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pressure       60 non-null     float64
#  1   dT             60 non-null     float64
#  2   Tp             60 non-null     int64
#  3   y_signal       60 non-null     float64
#  4   x_signal       60 non-null     float64
#  5   role           60 non-null     str
#  6   low_quality    60 non-null     bool
#  7   x_quality      60 non-null     float64
#  8   x_quality_ref  60 non-null     float64
#  9   y_quality      60 non-null     float64
#  10  y_quality_ref  60 non-null     float64
# dtypes: bool(1), float64(8), int64(1), str(1)
# memory usage: 5.2 KB

# %%
# Zad. 14.1

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

sns.histplot(df_meta['deltaT_label'], kde=False, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title('Rozkład temperatur (deltaT)')

sns.histplot(df_meta['pressure_corr_mpa'], kde=False, ax=axes[0, 1], color='salmon')
axes[0, 1].set_title('Rozkład ciśnień (MPa)')

df_meta['point_type'].value_counts().plot(kind='pie', autopct='%1.1f%%', ax=axes[0, 2])
axes[0, 2].set_title('Udział typów punktów (point_type)')

df_meta['series_id'].value_counts().head(10).plot(kind='bar', ax=axes[1, 0])
axes[1, 0].set_title('Rozkład 10 najczęstszych serii')

counts = df_meta['is_complete_pair'].value_counts()
counts.plot(kind='bar', ax=axes[1, 1], color=['green', 'red'])
axes[1, 1].set_title('Kompletne vs niekompletne pary X/Y')
labels = [('Kompletne' if x == True else 'Niekompletne') for x in counts.index]
axes[1, 1].set_xticks(range(len(labels)))
axes[1, 1].set_xticklabels(labels, rotation=0)

fig.delaxes(axes[1, 2])
plt.tight_layout()
plt.show()

# %%
# Zad. 14.2

df_plot = df_summary[df_summary["ref"].notna()].copy()

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# mu_X vs dT i mu_Y vs dT
sns.scatterplot(data=df_plot, x='dT', y='mu_X', ax=axes[0], label='mu_X', alpha=0.6)
sns.scatterplot(data=df_plot, x='dT', y='mu_Y', ax=axes[0], label='mu_Y', alpha=0.6)
axes[0].set_title('Przesunięcie widmowe vs Temperatura')
axes[0].set_ylabel('mu [GHz]')

# mu_X vs p i mu_Y vs p
df_p = df_plot[df_plot['dT'] == 0]
sns.regplot(data=df_p, x='pressure', y='mu_X', ax=axes[1], label='mu_X')
sns.regplot(data=df_p, x='pressure', y='mu_Y', ax=axes[1], label='mu_Y')
axes[1].set_title('Przesunięcie widmowe vs Ciśnienie (dla dT=0)')
axes[1].set_ylabel('mu [GHz]')

plt.tight_layout()
plt.show()

# %%
# Zad. 14.3

features = ['dT', 'pressure', 'mu_X', 'mu_Y', 'diff_XY', 'mean_XY']
corr_matrix = df_plot[features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Macierz korelacji cech bazowych z parametrami docelowymi')
plt.show()

corr_p_diff = corr_matrix.loc['pressure', 'diff_XY']
corr_p_muX = corr_matrix.loc['pressure', 'mu_X']
corr_T_mean = corr_matrix.loc['dT', 'mean_XY']
corr_T_muX = corr_matrix.loc['dT', 'mu_X']

print(f"Korelacja p z diff_XY: {corr_p_diff:.4f} (vs mu_X: {corr_p_muX:.4f})")
print(f"Korelacja dT z mean_XY: {corr_T_mean:.4f} (vs mu_X: {corr_T_muX:.4f})")

print("Wnioski:")
if abs(corr_p_diff) > abs(corr_p_muX):
    print(" -diff_XY poprawia korelację z ciśnieniem względem pojedynczego kanału.")
else:
    print(" -diff_XY nie wykazuje silniejszej korelacji liniowej z ciśnieniem niż mu_X.")

if abs(corr_T_mean) > abs(corr_T_muX):
    print(" -mean_XY poprawia korelację z temperaturą względem pojedynczego kanału.")
else:
    print(" -mean_XY nie wykazuje silniejszej korelacji liniowej z temperaturą niż mu_X.")
# Out:
# Korelacja p z diff_XY: 0.9996 (vs mu_X: 0.9969)
# Korelacja dT z mean_XY: 0.1052 (vs mu_X: -0.0712)
# Wnioski:
#  -diff_XY poprawia korelację z ciśnieniem względem pojedynczego kanału.
#  -mean_XY poprawia korelację z temperaturą względem pojedynczego kanału.
