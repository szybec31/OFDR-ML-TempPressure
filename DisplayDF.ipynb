# %%
import pandas as pd
from build_df import build_dataframe
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

# Load and display DataFrame
df = build_dataframe()
df
# Out:
# Number of founded .txt files:  2540
#                                                           source_path temp_folder_label  deltaT_label  T_plate_label series_id channel_raw channel_norm pressure_raw_label
# 0      PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-1.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa
# 1     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-10.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa
# 2      PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-2.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa
# 3      PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-3.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa
# 4      PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-4.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa
# ...                                                               ...               ...           ...            ...       ...         ...          ...                ...
# 2535  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_channel_2-9MPa-5.txt     DT45.7_T75_27          45.7             75        27         CH2            X               9MPa
# 2536  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_channel_2-9MPa-6.txt     DT45.7_T75_27          45.7             75        27         CH2            X               9MPa
# 2537  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_channel_2-9MPa-7.txt     DT45.7_T75_27          45.7             75        27         CH2            X               9MPa
# 2538  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_channel_2-9MPa-8.txt     DT45.7_T75_27          45.7             75        27         CH2            X               9MPa
# 2539  PAKA_AI\DT45.7_T75_27\27_CH2_X_SLOW\Switch_channel_2-9MPa-9.txt     DT45.7_T75_27          45.7             75        27         CH2            X               9MPa
#
# [2540 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2540 entries, 0 to 2539
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   source_path         2540 non-null   str
#  1   temp_folder_label   2540 non-null   str
#  2   deltaT_label        2540 non-null   float64
#  3   T_plate_label       2540 non-null   int64
#  4   series_id           2540 non-null   str
#  5   channel_raw         2540 non-null   str
#  6   channel_norm        2540 non-null   str
#  7   pressure_raw_label  2540 non-null   str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 158.9 KB

# %%
df.isnull().sum()
# Out:
# source_path           0
# temp_folder_label     0
# deltaT_label          0
# T_plate_label         0
# series_id             0
# channel_raw           0
# channel_norm          0
# pressure_raw_label    0
# dtype: int64

# %%
df["deltaT_label"].unique()
# Out:
# array([ 0. , 16.2, 20.5, 24.7, 27.4, 33. , 37.5, 41.8, 45.7])

# %%
df["T_plate_label"].unique()
# Out:
# array([23, 42, 45, 50, 55, 60, 65, 70, 75])

# %%
df["channel_norm"].unique()
# Out:
# <StringArray>
# ['Y', 'X']
# Length: 2, dtype: str

# %%
df["pressure_corr_mpa"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Politechnika\Python_project\OFDR-ML-TempPressure\myvenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pressure_corr_mpa'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df["pressure_corr_mpa"].unique()
#
# File C:\Politechnika\Python_project\OFDR-ML-TempPressure\myvenv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File C:\Politechnika\Python_project\OFDR-ML-TempPressure\myvenv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'pressure_corr_mpa'
