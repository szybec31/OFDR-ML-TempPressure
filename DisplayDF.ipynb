# %%
import pandas as pd
from build_df import build_dataframe
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

# Load and display DataFrame
df = build_dataframe()
df
# Out:
# Number of .txt files found:  2540
#                                                           source_path temp_folder_label  deltaT_label  T_plate_label series_id channel_raw channel_norm pressure_raw_label  pressure_corr_mpa      point_type                                                          pair_id  is_complete_pair                                                reference_zero_id  is_temp_calibration  is_pressure_calibration  is_joint_regression  is_repeatability_test
# 0      PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0.5MPa-1.txt        DT0_T23_15           0.0             23        15         CH1            Y             0.5MPa                0.5  pressure_point   PAKA_AI\DT0_T23_15\15_CH2_X_SLOW\Switch_channel_2-0.5MPa-1.txt              True     PAKA_AI\DT0_T23_15\15_CH1_Y_FAST\Switch_channel_1-0MPa-1.txt                False                     True                 True                  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2540 entries, 0 to 2539
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   source_path              2540 non-null   str
#  1   temp_folder_label        2540 non-null   str
#  2   deltaT_label             2540 non-null   float64
#  3   T_plate_label            2540 non-null   int64
#  4   series_id                2540 non-null   str
#  5   channel_raw              2540 non-null   str
#  6   channel_norm             2540 non-null   str
#  7   pressure_raw_label       2540 non-null   str
#  8   pressure_corr_mpa        2540 non-null   float64
#  9   point_type               2540 non-null   str
#  10  pair_id                  2540 non-null   str
#  11  is_complete_pair         2540 non-null   bool
#  12  reference_zero_id        2540 non-null   str
#  13  is_temp_calibration      2540 non-null   bool
# ...

# %%
df.isnull().sum()
# Out:
# source_path                0
# temp_folder_label          0
# deltaT_label               0
# T_plate_label              0
# series_id                  0
# channel_raw                0
# channel_norm               0
# pressure_raw_label         0
# pressure_corr_mpa          0
# point_type                 0
# pair_id                    0
# is_complete_pair           0
# reference_zero_id          0
# is_temp_calibration        0
# is_pressure_calibration    0
# is_joint_regression        0
# is_repeatability_test      0
# dtype: int64

# %%
df["deltaT_label"].unique()
# Out:
# array([ 0. , 16.2, 20.5, 24.7, 27.4, 33. , 37.5, 41.8, 45.7])

# %%
df["T_plate_label"].unique()
# Out:
# array([23, 42, 45, 50, 55, 60, 65, 70, 75])

# %%
df["pressure_corr_mpa"].value_counts()
# Out:
# np.int64(2540)

# %%
df["pressure_raw_label"].unique()
# Out:
# <StringArray>
# [ '0.5MPa',    '0MPa',   '10MPa',   '11MPa',    '1MPa',    '2MPa',    '3MPa',
#     '4MPa',    '5MPa',    '6MPa',    '7MPa',    '8MPa',    '9MPa',  '0.1MPa',
#   '0.2MPa', '0.01MPa']
# Length: 16, dtype: str

# %%
df["role"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kamil\Desktop\Szkola\Studia PWR\Semestr 8\Projekt Naukowy\OFDR-ML-TempPressure\myvenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'role'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df["point_type"].unique()
# Out:
# <StringArray>
# ['pressure_point', 'zero_start', 'zero_end']
# Length: 3, dtype: str

# %%
df["is_complete_pair"].unique()
# Out:
# array([ True])

# %%
db = pd.read_csv("Output_files/paired_features.csv")
db
# Out:
#       series_id  pressure    dT  Tp       mu_Y       mu_X     std_Y     std_X     irq_Y     irq_X  is_temp_calibration  is_pressure_calibration  is_joint_regression  is_repeatability_test  low_quality
# 0            15       0.5   0.0  23  -1.161463   0.177174  0.148690  0.080380  0.208516  0.103947                False                     True                 True                  False        False
# 1            15       0.5   0.0  23  -1.134390   0.160566  0.142894  0.082127  0.211629  0.107682                False                     True                 True                  False        False
# 2            15       0.5   0.0  23  -1.149027   0.174392  0.144446  0.078795  0.204315  0.100057                False                     True                 True                  False        False
# ...

# %%
db["series_id"].unique()
# Out:
# array([15,  2, 19, 20, 16, 21, 25, 26, 27])

# %%
(db[db["Tp"] == 23]["is_pressure_calibration"])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 125    True
# 126    True
# 127    True
# 128    True
# 129    True
# Name: is_pressure_calibration, Length: 130, dtype: bool

# %%
db[db["dT"] == 0]
# Out:
#      series_id  pressure   dT  Tp       mu_Y      mu_X     std_Y     std_X     irq_Y     irq_X  is_temp_calibration  is_pressure_calibration  is_joint_regression  is_repeatability_test  low_quality
# 0           15       0.5  0.0  23  -1.161463  0.177174  0.148690  0.080380  0.208516  0.103947                False                     True                 True                  False        False
# 1           15       0.5  0.0  23  -1.134390  0.160566  0.142894  0.082127  0.211629  0.107682                False                     True                 True                  False        False
# 2           15       0.5  0.0  23  -1.149027  0.174392  0.144446  0.078795  0.204315  0.100057                False                     True                 True                  False        False
# 3           15       0.5  0.0  23  -1.142649  0.179321  0.144685  0.080948  0.201047  0.102702                False                     True                 True                  False        False
# ...
